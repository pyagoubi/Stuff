# %% [markdown]
# <a href="https://colab.research.google.com/github/pyagoubi/Stuff/blob/main/mun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns

# %%
mun = pd.read_csv('/content/drive/MyDrive/mun/mun.csv')
services = pd.read_csv('/content/drive/MyDrive/mun/services.csv')

mun_list = mun['municipalities'].to_list()
serv_list = services['services'].to_list()

# %%
den = pd.read_excel('/content/drive/MyDrive/mun/density.xlsx')

# %%
den
# Out:
#      Municipality  category     Residents     Bakery  Primary School  \
# 0          Zürich         1   4813.934706   1.217154        0.455011
# 1          Genève         1  12800.566394   4.971680        3.775960
# 2           Basel         1   7244.202595   2.553370        1.590624
# 3        Lausanne         1   3399.057288   1.450326        0.749335
# 4            Bern         1   2602.015113   1.162565        0.852548
# ...           ...       ...           ...        ...             ...
# 2131     Linescio         3      6.212121   6.363636        0.151515
# 2132    Cerentino         3      1.791045   1.741294        0.049751
# 2133     Schelten         3      6.137184  10.830325        0.180505
# 2134  Kammersrohr         3     35.106383  63.829787        9.574468
# 2135       Bister         3      5.689655   6.206897        4.482759
#
#              Bar  Grocery Shop  Kindergarten   Nursery  Restaurant      Kiosk  \
# ...

# %%
import matplotlib.pyplot as plt

sns.scatterplot(data=den[den['category']==1], x = 'Residents', y= 'Restaurant')
plt.xlabel('Population density')
plt.ylabel('Restaurant Density')
# Out:
# Text(0, 0.5, 'Restaurant Density')
