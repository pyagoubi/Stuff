# %% [markdown]
# <a href="https://colab.research.google.com/github/pyagoubi/Stuff/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install bt

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from torch.utils.data import dataloader
from torch.utils.data import DataLoader
#import bt as bt
import os, sys, itertools, urllib, io
import datetime as dt
import pandas as pd
import pandas_datareader as dr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import Dataset

# set cpu or gpu enabled device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu').type

split_fraction = 0.8
time_steps = 20 # number of predictor timesteps
horizon = 1 # number of timesteps to be predicted
sequence_length = time_steps + horizon # determine sequence length
learning_rate=0.01
num_epochs=100


data_raw = pd.read_csv('/content/drive/MyDrive/stock predict/1D.csv')
#features = ['open', 'high', 'low', 'close', 'rsi', 'adx', 'cci', 'ema', 'stoch', 'trend_macd', 'momentum_stoch', 'volatility_atr']
cols = ['time','close']
#features = ['close']
data = data_raw[cols].copy()

# %%
plt.figure(figsize = (20,8))
plt.plot(data[['close']])
plt.xticks(range(0,data.shape[0],500),data['time'].loc[::500],rotation=45)
plt.title("Close Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.show()

# %%
data = data[['close']].copy()

split_row = int(data.shape[0] * split_fraction)

train_data = data.iloc[:split_row]
valid_data = data.iloc[split_row:]

scaler = MinMaxScaler(feature_range=(-1, 1))
data['close'] = scaler.fit_transform(data['close'].values.reshape(-1,1))

# %%
def create_sequences(df, seq_length):
    df = df.values  # Convert DataFrame to numpy array
    
    n = df.shape[0]
    xs = np.zeros((n - seq_length, seq_length, df.shape[1]))
    ys = np.zeros((n - seq_length, 1))
    
    for i in range(n - seq_length):
        xs[i] = df[i:(i+seq_length)]
        ys[i] = df[i+seq_length, -1]  # predict the 'return' column one step ahead
    
    # Convert to PyTorch tensors
    X = torch.from_numpy(xs)
    y = torch.from_numpy(ys)
    
    return X, y
train_data, train_target = create_sequences(train_data, sequence_length)
valid_data, valid_target = create_sequences(valid_data, sequence_length)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):

      super(LSTM, self).__init__()
      
      self.hidden_size = hidden_size
      self.num_layers = num_layers
      
      self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
      
      self.fc1 = nn.Linear(hidden_size, output_size)

    def forward(self, x):

      h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device) 
      c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device) 

      h0.requires_grad = True
      c0.requires_grad = True

    
      #out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
      out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
      out = self.fc1(out[:, -1, :])
      #out = self.fc2(out)
      #out = self.fc3(out)    
      return out

# %%
import time

def train(model, train, train_target, valid, valid_target, learning_rate, num_epochs):

  criterion = torch.nn.MSELoss(reduction='mean')
  optimiser = torch.optim.Adam(model.parameters(), lr=learning_rate)

  hist = np.zeros(num_epochs)
  start_time = time.time()
  lstm = []

  train = train.float().to(device)  # Convert to float
  train_target = train_target.float().to(device)  # Convert to float
  valid = valid.float().to(device)  # Convert to float
  valid_target = valid_target.float().to(device)  # Convert to float

  best_loss = float('inf')

  for epoch in range(num_epochs):

    model.train()
    y_train_pred = model(train)
    train_loss = criterion(y_train_pred, train_target)
    optimiser.zero_grad()
    train_loss.backward()
    optimiser.step()

    model.eval()
    outputs = model(valid)
    val_loss = criterion(outputs, valid_target)

    print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss.item():.4f}, '
              f'Validation Loss: {val_loss.item():.4f}')
    
    if val_loss < best_loss:
      best_loss = val_loss
      torch.save(model, '/content/drive/MyDrive/stock predict/prediction_model.pt')
      best_epoch = epoch

 

num_features = train_data.shape[-1]  # X is your input data
model = LSTM(input_size=num_features, hidden_size=16, num_layers=3, output_size=1)
model = model.to(device)
train(model, train_data, train_target, valid_data, valid_target, learning_rate, num_epochs=100)

# %%
model = torch.load('/content/drive/MyDrive/stock predict/prediction_model.pt')
model = model.to(device)
model.eval()
train_data = train_data.float() # Convert to float
y_train_pred = model(train_data)

actuals = pd.DataFrame(scaler.inverse_transform(train_target.detach().cpu().numpy()))
preds = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().cpu().numpy()))

train = data[0:len(actuals)]
valid = actuals
valid['Predictions'] = preds
plt.figure(figsize=(20,8))
plt.plot(valid[len(valid)-500:], color = 'blue', label = 'Actual Close Price')
plt.plot(valid[len(valid)-500:]['Predictions'], color = 'red', label = 'Predicted Close Price')
plt.title('SBIN price prediction')
plt.legend()
plt.show()

# %%
train_data.shape
# Out:
# torch.Size([9881, 21, 1])

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from torch.utils.data import dataloader
from torch.utils.data import DataLoader
#import bt as bt
import os, sys, itertools, urllib, io
import datetime as dt
import pandas as pd
import pandas_datareader as dr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import Dataset

split_fraction = 0.8
time_steps = 20 # number of predictor timesteps
horizon = 1 # number of timesteps to be predicted
sequence_length = time_steps + horizon # determine sequence length
learning_rate=0.01
num_epochs=100



tech_daily_raw = pd.read_csv('/content/drive/MyDrive/stock predict/1D.csv')
#features = ['open', 'high', 'low', 'close', 'rsi', 'adx', 'cci', 'ema', 'stoch', 'trend_macd', 'momentum_stoch', 'volatility_atr']
cols = ['close']
features = ['close']
tech_daily = tech_daily_raw[cols].copy()


# init deterministic seed
seed_value = 1234
np.random.seed(seed_value) # set numpy seed
torch.manual_seed(seed_value); # set pytorch seed CPU

# set cpu or gpu enabled device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu').type

# init deterministic GPU seed
torch.cuda.manual_seed(seed_value)

# log type of device enabled
now = dt.datetime.utcnow().strftime("%Y%m%d-%H:%M:%S")
print('[LOG {}] notebook with \'{}\' computation enabled'.format(str(now), str(device)))


tech_daily['return'] = (np.log(tech_daily['close']) - np.log(tech_daily['close'].shift(1)))*100
features =  ['return']
# #features = ['return']
tech_daily = tech_daily[features]
tech_daily = tech_daily[1:]


#scaler = MinMaxScaler()
# tech_daily_scaled = pd.DataFrame(columns = tech_daily.columns)

#scaler = StandardScaler()
#tech_daily_scaled[features] = pd.DataFrame(scaler.fit_transform(tech_daily), columns = features)
# tech_daily_scaled[features] = scaler.fit_transform(tech_daily[features])
# tech_daily_scaled['return'] = tech_daily['return']


# tech_daily_scaled = tech_daily_scaled[1:]
# del tech_daily_scaled
# tech_daily_scaled = tech_daily.copy()


split_row = int(tech_daily.shape[0] * split_fraction)

#tech_daily_scaled = tech_daily_scaled[1:]

train_stock_data_return = tech_daily.iloc[:split_row]
valid_stock_data_return = tech_daily.iloc[split_row:]

def create_sequences(df, seq_length):
    df = df.values  # Convert DataFrame to numpy array
    
    n = df.shape[0]
    xs = np.zeros((n - seq_length, seq_length, df.shape[1]))
    ys = np.zeros((n - seq_length, 1))
    
    for i in range(n - seq_length):
        xs[i] = df[i:(i+seq_length)]
        ys[i] = df[i+seq_length, -1]  # predict the 'return' column one step ahead
    
    # Convert to PyTorch tensors
    X = torch.from_numpy(xs)
    y = torch.from_numpy(ys)
    
    return X, y


train, train_target = create_sequences(train_stock_data_return, sequence_length)
valid, valid_target = create_sequences(valid_stock_data_return, sequence_length)

full_set, full_target = create_sequences(tech_daily, sequence_length)



from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]




class MultivariateLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):

      super(MultivariateLSTM, self).__init__()
      
      self.hidden_size = hidden_size
      self.num_layers = num_layers
      
      self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
      
      self.fc1 = nn.Linear(hidden_size, 10)
      self.fc2 = nn.Linear(10, 1)
      #self.fc3 = nn.Linear(10, output_size)

      # define non-linar activation function
      self.tanh = nn.Tanh() # the non-linarity

      self.lr = nn.LeakyReLU()

    def forward(self, x):


      h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_().to(x.device)
      c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_().to(x.device)
    
      out, _ = self.lstm(x, (h0, c0))


      out = self.tanh(self.fc1(out[:, -1, :]))
      out = self.fc2(out)

      #out = self.fc3(out)

      
      return out

      #predictions = []
      # for xy in x.chunk(x.size(1), dim=1):


        
      #   out, _ = self.lstm(xy, (h0, c0))
        
      #   out = self.tanh(self.fc1(out[:, -1, :]))
      #   out = self.fc2(out)
      #   #out = self.fc3(out)

      #   predictions += [out]

      #   print(predictions)

      # # stack predictions
      # predictions = torch.stack(predictions, 1).squeeze(2)

      # # return predictions
      # return predictions
        
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
    elif type(m) == nn.LSTM:
        for param in m.parameters():
            if len(param.shape) >= 2:
                torch.nn.init.orthogonal_(param.data)
            else:
                torch.nn.init.normal_(param.data)


class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))



def train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    #criterion = nn.MSELoss()
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    train_dataset = SequenceDataset(train, train_target)
    val_dataset = SequenceDataset(valid, valid_target)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = float('inf')

    train_losses = []
    val_losses = []

    best_predictions = []
    for epoch in range(num_epochs):
        model.train()
        train_epoch_losses = []
        for sequences, targets in train_loader:
            sequences = sequences.float().to(device)  # Convert to float
            targets = targets.float().to(device)  # Convert to float


            # Forward pass
            outputs = model(sequences)

            loss = criterion(outputs, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_epoch_losses.append(loss.item())

        model.eval()
        val_epoch_losses = []
        with torch.no_grad():
            for sequences, targets in val_loader:
                sequences = sequences.float().to(device)  # Convert to float
                targets = targets.float().to(device)  # Convert to float


                outputs = model(sequences)
                loss = criterion(outputs, targets)
                val_epoch_losses.append(loss.item())
     
        train_loss = np.mean(train_epoch_losses)
        val_loss = np.mean(val_epoch_losses)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
             
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, '
              f'Validation Loss: {val_loss:.4f}')


        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), 'best_model.pth')  # Save the model
            best_epoch = epoch


    # load best model weights
    model.load_state_dict(best_model_wts)

    print(f'Best Loss {best_loss}, Epoch = {best_epoch}')
    
    # Plot the train loss and validation loss per epoch
    plt.figure(figsize=(12, 8))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss per epoch')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # generate predictions based on the best model
    train_predictions = []
    valid_predictions = []
    with torch.no_grad():
        for sequences, _ in train_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)

            train_predictions.extend(outputs.cpu().numpy().flatten().tolist())

        for sequences, _ in val_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)
            valid_predictions.extend(outputs.cpu().numpy().flatten().tolist())

    return model

# Use the function:
num_features = train.shape[-1]  # X is your input data
model = MultivariateLSTM(input_size=num_features, hidden_size=40, num_layers=2, output_size=1)
model.apply(init_weights)
model = train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs)


def create_predictions(df, model, full_target):

  dataset = SequenceDataset(df, full_target)
  data_loader = DataLoader(dataset, batch_size=32, shuffle=True)
  model.eval()

  predictions = []
  with torch.no_grad():
      for sequences, _ in data_loader:
          sequences = sequences.float().to(device)
          outputs = model(sequences)
          predictions.extend(outputs.cpu().numpy().flatten().tolist())

  return predictions
predictions = create_predictions(full_set, model, full_target)


tech_daily = tech_daily[sequence_length:].copy()
tech_daily['predictions'] = predictions

plotting_df = tech_daily[len(tech_daily)-len(tech_daily):]


plt.figure(figsize=(20, 8))
plt.plot(plotting_df['return'], label='Real closing price')
plt.plot(plotting_df['predictions'], label='Predictions')
plt.title('Real vs Predictions')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [LOG 20230518-17:11:40] notebook with 'cuda' computation enabled
# Epoch 1/100, Train Loss: 0.5280, Validation Loss: 0.4102
# Epoch 2/100, Train Loss: 0.5226, Validation Loss: 0.4125
# Epoch 3/100, Train Loss: 0.5218, Validation Loss: 0.4065
# Epoch 4/100, Train Loss: 0.5230, Validation Loss: 0.4111
# Epoch 5/100, Train Loss: 0.5209, Validation Loss: 0.4155
# Epoch 6/100, Train Loss: 0.5233, Validation Loss: 0.4068
# Epoch 7/100, Train Loss: 0.5226, Validation Loss: 0.4114
# Epoch 8/100, Train Loss: 0.5217, Validation Loss: 0.4070
# Epoch 9/100, Train Loss: 0.5230, Validation Loss: 0.4116
# Epoch 10/100, Train Loss: 0.5229, Validation Loss: 0.4081
# Epoch 11/100, Train Loss: 0.5217, Validation Loss: 0.4069
# Epoch 12/100, Train Loss: 0.5214, Validation Loss: 0.4071
# Epoch 13/100, Train Loss: 0.5214, Validation Loss: 0.4066
# Epoch 14/100, Train Loss: 0.5208, Validation Loss: 0.4072
# Epoch 15/100, Train Loss: 0.5208, Validation Loss: 0.4071
# Epoch 16/100, Train Loss: 0.5211, Validation Loss: 0.4075
# Epoch 17/100, Train Loss: 0.5219, Validation Loss: 0.4143
# Epoch 18/100, Train Loss: 0.5212, Validation Loss: 0.4080
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b374cd7280c5> in <cell line: 309>()
#     307 model = MultivariateLSTM(input_size=num_features, hidden_size=40, num_layers=2, output_size=1)
#     308 model.apply(init_weights)
# --> 309 model = train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs)
#     310
#     311
#
# <ipython-input-23-b374cd7280c5> in train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs)
#     229
#     230             # Forward pass
# --> 231             outputs = model(sequences)
#     232
#     233             loss = criterion(outputs, targets)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-23-b374cd7280c5> in forward(self, x)
#     145       c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_().to(x.device)
#     146
# --> 147       out, _ = self.lstm(x, (h0, c0))
#     148
#     149
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     810         self.check_forward_args(input, hx, batch_sizes)
#     811         if batch_sizes is None:
# --> 812             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     814         else:
#
# KeyboardInterrupt:

# %%
predictions

# %%
len(tech_daily_raw)
# Out:
# 12378

# %%
def calculate_prices(df):
    prices = [df['close'].iloc[0]]
    for ret in df['return predictions'].iloc[1:]:
        prices.append(prices[-1] * (1 + ret))
    return prices

tech_daily['price prediction'] = calculate_prices(tech_daily)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-10ab3ff26fa9> in <cell line: 7>()
#       5     return prices
#       6
# ----> 7 tech_daily['price prediction'] = calculate_prices(tech_daily)
#
# <ipython-input-6-10ab3ff26fa9> in calculate_prices(df)
#       1 def calculate_prices(df):
# ----> 2     prices = [df['close'].iloc[0]]
#       3     for ret in df['return predictions'].iloc[1:]:
#       4         prices.append(prices[-1] * (1 + ret))
#       5     return prices
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'close'

# %%
tech_daily['close'].iloc[0]
