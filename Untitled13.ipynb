# %% [markdown]
# <a href="https://colab.research.google.com/github/pyagoubi/Stuff/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install bt

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from torch.utils.data import dataloader
from torch.utils.data import DataLoader
#import bt as bt
import os, sys, itertools, urllib, io
import datetime as dt
import pandas as pd
import pandas_datareader as dr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import Dataset

split_fraction = 0.8
time_steps = 20 # number of predictor timesteps
horizon = 1 # number of timesteps to be predicted
sequence_length = time_steps + horizon # determine sequence length



tech_daily_raw = pd.read_csv('/content/drive/MyDrive/stock predict/technical/1D_technical.csv')
#features = ['open', 'high', 'low', 'close', 'rsi', 'adx', 'cci', 'ema', 'stoch', 'trend_macd', 'momentum_stoch', 'volatility_atr']
cols = ['rsi', 'adx', 'cci', 'ema', 'stoch', 'close']
features = ['rsi', 'adx', 'cci', 'ema', 'stoch', 'close']
tech_daily = tech_daily_raw[cols].copy()

# init deterministic seed
seed_value = 1234
np.random.seed(seed_value) # set numpy seed
torch.manual_seed(seed_value); # set pytorch seed CPU

# set cpu or gpu enabled device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu').type

# init deterministic GPU seed
torch.cuda.manual_seed(seed_value)

# log type of device enabled
now = dt.datetime.utcnow().strftime("%Y%m%d-%H:%M:%S")
print('[LOG {}] notebook with \'{}\' computation enabled'.format(str(now), str(device)))


# tech_daily['return'] = np.log(tech_daily['close']) - np.log(tech_daily['close'].shift(1))
# #features = features + ['return']
# #features = ['return']
# tech_daily = tech_daily[features]


#scaler = MinMaxScaler()
# tech_daily_scaled = pd.DataFrame(columns = tech_daily.columns)

#scaler = StandardScaler()
#tech_daily_scaled[features] = pd.DataFrame(scaler.fit_transform(tech_daily), columns = features)
# tech_daily_scaled[features] = scaler.fit_transform(tech_daily[features])
# tech_daily_scaled['return'] = tech_daily['return']


# tech_daily_scaled = tech_daily_scaled[1:]
# del tech_daily_scaled
# tech_daily_scaled = tech_daily.copy()


split_row = int(tech_daily.shape[0] * split_fraction)

#tech_daily_scaled = tech_daily_scaled[1:]

train_stock_data_return = tech_daily.iloc[:split_row]
valid_stock_data_return = tech_daily.iloc[split_row:]

def create_sequences(df, seq_length):
    df = df.values  # Convert DataFrame to numpy array
    
    n = df.shape[0]
    xs = np.zeros((n - seq_length, seq_length, df.shape[1]))
    ys = np.zeros((n - seq_length, 1))
    
    for i in range(n - seq_length):
        xs[i] = df[i:(i+seq_length)]
        ys[i] = df[i+seq_length, -1]  # predict the 'return' column one step ahead
    
    # Convert to PyTorch tensors
    X = torch.from_numpy(xs)
    y = torch.from_numpy(ys)
    
    return X, y


train, train_target = create_sequences(train_stock_data_return, sequence_length)
valid, valid_target = create_sequences(valid_stock_data_return, sequence_length)

full_set, full_target = create_sequences(tech_daily, sequence_length)


from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]




class MultivariateLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(MultivariateLSTM, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        self.fc1 = nn.Linear(hidden_size, 10)
        self.fc2 = nn.Linear(10, 1)
        #self.fc3 = nn.Linear(10, output_size)

        # define non-linar activation function
        self.tanh = nn.Tanh() # the non-linarity

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        
        out = self.tanh(self.fc1(out[:, -1, :]))
        out = self.fc2(out)
        #out = self.fc3(out)
        
        return out

class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))



def train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    criterion = nn.MSELoss()
    #criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    train_dataset = SequenceDataset(train, train_target)
    val_dataset = SequenceDataset(valid, valid_target)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = float('inf')

    train_losses = []
    val_losses = []

    best_predictions = []
    for epoch in range(num_epochs):
        model.train()
        train_epoch_losses = []
        for sequences, targets in train_loader:
            sequences = sequences.float().to(device)  # Convert to float
            targets = targets.float().to(device)  # Convert to float


            # Forward pass
            outputs = model(sequences)
            loss = criterion(outputs, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_epoch_losses.append(loss.item())

        model.eval()
        val_epoch_losses = []
        with torch.no_grad():
            for sequences, targets in val_loader:
                sequences = sequences.float().to(device)  # Convert to float
                targets = targets.float().to(device)  # Convert to float


                outputs = model(sequences)
                loss = criterion(outputs, targets)
                val_epoch_losses.append(loss.item())
     
        train_loss = np.mean(train_epoch_losses)
        val_loss = np.mean(val_epoch_losses)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
             
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, '
              f'Validation Loss: {val_loss:.4f}')


        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), 'best_model.pth')  # Save the model
            best_epoch = epoch


    # load best model weights
    model.load_state_dict(best_model_wts)

    print(f'Best Loss {best_loss}, Epoch = {best_epoch}')
    
    # Plot the train loss and validation loss per epoch
    plt.figure(figsize=(12, 8))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss per epoch')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # generate predictions based on the best model
    train_predictions = []
    valid_predictions = []
    with torch.no_grad():
        for sequences, _ in train_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)
            train_predictions.extend(outputs.cpu().numpy().flatten().tolist())

        for sequences, _ in val_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)
            valid_predictions.extend(outputs.cpu().numpy().flatten().tolist())

    return model

# Use the function:
num_features = train.shape[-1]  # X is your input data
model = MultivariateLSTM(input_size=num_features, hidden_size=40, num_layers=2, output_size=1)
model = train_model(model, train, train_target, valid, valid_target, learning_rate=0.01, num_epochs=100)


def create_predictions(df, model):

  dataset = SequenceDataset(df, full_target)
  data_loader = DataLoader(dataset, batch_size=32, shuffle=True)
  model.eval()

  predictions = []
  with torch.no_grad():
      for sequences, _ in data_loader:
          sequences = sequences.float().to(device)
          outputs = model(sequences)
          predictions.extend(outputs.cpu().numpy().flatten().tolist())

  return predictions
predictions = create_predictions(full_set, model)


tech_daily = tech_daily[sequence_length:]
tech_daily['predictions'] = predictions

plotting_df = tech_daily[len(tech_daily)-len(tech_daily):]


plt.figure(figsize=(20, 8))
plt.plot(plotting_df['close'], label='Real closing price')
plt.plot(plotting_df['predictions'], label='Predictions')
plt.title('Real vs Predictions')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [LOG 20230517-13:43:17] notebook with 'cuda' computation enabled
# Epoch 1/100, Train Loss: 6108.5286, Validation Loss: 4957.6980
# Epoch 2/100, Train Loss: 3086.1343, Validation Loss: 2490.4151
# Epoch 3/100, Train Loss: 1423.4728, Validation Loss: 1151.3801
# Epoch 4/100, Train Loss: 611.6419, Validation Loss: 501.5759
# Epoch 5/100, Train Loss: 274.7352, Validation Loss: 222.0626
# Epoch 6/100, Train Loss: 159.3562, Validation Loss: 113.1209
# Epoch 7/100, Train Loss: 127.8191, Validation Loss: 73.3628
# Epoch 8/100, Train Loss: 121.2393, Validation Loss: 59.2244
# Epoch 9/100, Train Loss: 120.0832, Validation Loss: 54.0462
# Epoch 10/100, Train Loss: 119.8850, Validation Loss: 52.5204
# Epoch 11/100, Train Loss: 119.8948, Validation Loss: 52.0429
# Epoch 12/100, Train Loss: 119.9377, Validation Loss: 51.8394
# Epoch 13/100, Train Loss: 119.8152, Validation Loss: 52.1483
# Epoch 14/100, Train Loss: 119.8985, Validation Loss: 52.3428
# Epoch 15/100, Train Loss: 119.9224, Validation Loss: 52.8696
# Epoch 16/100, Train Loss: 119.9341, Validation Loss: 51.4091
# Epoch 17/100, Train Loss: 119.9565, Validation Loss: 51.6706
# Epoch 18/100, Train Loss: 119.9182, Validation Loss: 49.1856
# Epoch 19/100, Train Loss: 119.8873, Validation Loss: 52.1504
# Epoch 20/100, Train Loss: 119.7916, Validation Loss: 56.2548
# Epoch 21/100, Train Loss: 119.9629, Validation Loss: 54.1942
# Epoch 22/100, Train Loss: 120.0939, Validation Loss: 53.2070
# Epoch 23/100, Train Loss: 119.8325, Validation Loss: 47.4200
# Epoch 24/100, Train Loss: 119.9750, Validation Loss: 52.4657
# Epoch 25/100, Train Loss: 119.8049, Validation Loss: 59.3367
# Epoch 26/100, Train Loss: 120.0645, Validation Loss: 57.1385
# Epoch 27/100, Train Loss: 119.9951, Validation Loss: 55.4380
# Epoch 28/100, Train Loss: 119.8528, Validation Loss: 54.0376
# Epoch 29/100, Train Loss: 119.9769, Validation Loss: 47.1909
# Epoch 30/100, Train Loss: 119.9793, Validation Loss: 53.6842
# Epoch 31/100, Train Loss: 119.9532, Validation Loss: 55.2695
# Epoch 32/100, Train Loss: 119.9165, Validation Loss: 55.3846
# Epoch 33/100, Train Loss: 120.0713, Validation Loss: 50.4340
# Epoch 34/100, Train Loss: 120.0712, Validation Loss: 49.2514
# Epoch 35/100, Train Loss: 120.0743, Validation Loss: 57.2539
# Epoch 36/100, Train Loss: 120.0201, Validation Loss: 51.0364
# Epoch 37/100, Train Loss: 119.9829, Validation Loss: 56.2518
# Epoch 38/100, Train Loss: 119.9007, Validation Loss: 49.7318
# Epoch 39/100, Train Loss: 120.0791, Validation Loss: 47.1433
# Epoch 40/100, Train Loss: 119.9006, Validation Loss: 59.5799
# Epoch 41/100, Train Loss: 119.8294, Validation Loss: 50.7453
# Epoch 42/100, Train Loss: 119.9546, Validation Loss: 53.4701
# Epoch 43/100, Train Loss: 120.0964, Validation Loss: 52.4384
# Epoch 44/100, Train Loss: 120.0261, Validation Loss: 55.4181
# Epoch 45/100, Train Loss: 119.9377, Validation Loss: 47.1091
# Epoch 46/100, Train Loss: 120.0712, Validation Loss: 53.4039
# Epoch 47/100, Train Loss: 119.9297, Validation Loss: 56.2364
# Epoch 48/100, Train Loss: 119.9158, Validation Loss: 52.6149
# Epoch 49/100, Train Loss: 120.0798, Validation Loss: 51.1821
# Epoch 50/100, Train Loss: 120.0831, Validation Loss: 48.1450
# Epoch 51/100, Train Loss: 119.9796, Validation Loss: 53.8881
# Epoch 52/100, Train Loss: 119.9923, Validation Loss: 50.4573
# Epoch 53/100, Train Loss: 120.0266, Validation Loss: 50.9857
# Epoch 54/100, Train Loss: 120.1051, Validation Loss: 52.3078
# Epoch 55/100, Train Loss: 120.0221, Validation Loss: 55.5346
# Epoch 56/100, Train Loss: 119.9409, Validation Loss: 53.3898
# Epoch 57/100, Train Loss: 119.9994, Validation Loss: 50.9413
# Epoch 58/100, Train Loss: 119.9990, Validation Loss: 46.7004
# Epoch 59/100, Train Loss: 120.1206, Validation Loss: 53.9123
# Epoch 60/100, Train Loss: 120.0838, Validation Loss: 56.1084
# Epoch 61/100, Train Loss: 120.0105, Validation Loss: 51.7321
# Epoch 62/100, Train Loss: 119.9916, Validation Loss: 53.4569
# Epoch 63/100, Train Loss: 120.0185, Validation Loss: 50.8287
# Epoch 64/100, Train Loss: 119.9259, Validation Loss: 51.4512
# Epoch 65/100, Train Loss: 119.9283, Validation Loss: 48.6862
# Epoch 66/100, Train Loss: 120.0109, Validation Loss: 53.2249
# Epoch 67/100, Train Loss: 120.1105, Validation Loss: 54.4288
# Epoch 68/100, Train Loss: 119.9540, Validation Loss: 59.7346
# Epoch 69/100, Train Loss: 119.9302, Validation Loss: 49.8103
# Epoch 70/100, Train Loss: 120.0804, Validation Loss: 53.7601
# Epoch 71/100, Train Loss: 120.0376, Validation Loss: 56.5290
# Epoch 72/100, Train Loss: 119.9068, Validation Loss: 52.9253
# Epoch 73/100, Train Loss: 120.0261, Validation Loss: 50.1389
# Epoch 74/100, Train Loss: 120.0625, Validation Loss: 55.0749
# Epoch 75/100, Train Loss: 119.9950, Validation Loss: 54.1004
# Epoch 76/100, Train Loss: 120.0250, Validation Loss: 51.2411
# Epoch 77/100, Train Loss: 119.9260, Validation Loss: 54.9948
# Epoch 78/100, Train Loss: 119.9830, Validation Loss: 54.9139
# Epoch 79/100, Train Loss: 119.9287, Validation Loss: 52.0722
# Epoch 80/100, Train Loss: 119.9212, Validation Loss: 48.5796
# Epoch 81/100, Train Loss: 119.9081, Validation Loss: 55.0799
# Epoch 82/100, Train Loss: 119.9651, Validation Loss: 48.2484
# Epoch 83/100, Train Loss: 119.8810, Validation Loss: 50.7345
# Epoch 84/100, Train Loss: 119.9917, Validation Loss: 50.4834
# Epoch 85/100, Train Loss: 120.2465, Validation Loss: 47.8596
# Epoch 86/100, Train Loss: 119.9450, Validation Loss: 55.7066
# Epoch 87/100, Train Loss: 120.0260, Validation Loss: 53.1121
# Epoch 88/100, Train Loss: 119.9340, Validation Loss: 48.5780
# Epoch 89/100, Train Loss: 119.9351, Validation Loss: 54.7655
# Epoch 90/100, Train Loss: 119.9949, Validation Loss: 49.6826
# Epoch 91/100, Train Loss: 120.0461, Validation Loss: 54.1721
# Epoch 92/100, Train Loss: 119.9516, Validation Loss: 55.0418
# Epoch 93/100, Train Loss: 120.1561, Validation Loss: 49.3794
# Epoch 94/100, Train Loss: 120.0768, Validation Loss: 46.7680
# Epoch 95/100, Train Loss: 119.9959, Validation Loss: 56.7075
# Epoch 96/100, Train Loss: 119.9756, Validation Loss: 47.5666
# Epoch 97/100, Train Loss: 120.0133, Validation Loss: 48.0064
# Epoch 98/100, Train Loss: 119.9521, Validation Loss: 52.2193
# Epoch 99/100, Train Loss: 120.1133, Validation Loss: 52.8886
# Epoch 100/100, Train Loss: 119.9983, Validation Loss: 57.5412
# Best Loss 46.700448549787204, Epoch = 57
# <ipython-input-10-996a15c7b1e2>:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_daily['predictions'] = predictions

# %%
def calculate_prices(df):
    prices = [df['close'].iloc[0]]
    for ret in df['return predictions'].iloc[1:]:
        prices.append(prices[-1] * (1 + ret))
    return prices

tech_daily['price prediction'] = calculate_prices(tech_daily)

# %%
tech_daily['close'].iloc[0]
