# %% [markdown]
# <a href="https://colab.research.google.com/github/pyagoubi/Stuff/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install bt

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from torch.utils.data import dataloader
#import bt as bt
import os, sys, itertools, urllib, io
import datetime as dt
import pandas as pd
import pandas_datareader as dr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import Dataset

# %%
tech_daily_raw = pd.read_csv('/content/drive/MyDrive/stock predict/technical/1D_technical.csv')
#features = ['open', 'high', 'low', 'close', 'rsi', 'adx', 'cci', 'ema', 'stoch', 'trend_macd', 'momentum_stoch', 'volatility_atr']
cols = ['rsi', 'adx', 'cci', 'ema', 'stoch', 'close']
features = ['rsi', 'adx', 'cci', 'ema', 'stoch']
tech_daily = tech_daily_raw[cols].copy()

# init deterministic seed
seed_value = 1234
np.random.seed(seed_value) # set numpy seed
torch.manual_seed(seed_value); # set pytorch seed CPU

# set cpu or gpu enabled device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu').type

# init deterministic GPU seed
torch.cuda.manual_seed(seed_value)

# log type of device enabled
now = dt.datetime.utcnow().strftime("%Y%m%d-%H:%M:%S")
print('[LOG {}] notebook with \'{}\' computation enabled'.format(str(now), str(device)))
# Out:
# [LOG 20230517-11:50:05] notebook with 'cuda' computation enabled

# %%
# tech_daily['return'] = np.log(tech_daily['close']) - np.log(tech_daily['close'].shift(1))

# #features = features + ['return']
# #features = ['return']

# tech_daily = tech_daily[features]

# %%
#scaler = MinMaxScaler()
tech_daily_scaled = pd.DataFrame(columns = tech_daily.columns)

scaler = StandardScaler()
#tech_daily_scaled[features] = pd.DataFrame(scaler.fit_transform(tech_daily), columns = features)

tech_daily_scaled[features] = scaler.fit_transform(tech_daily[features])
tech_daily_scaled['close'] = tech_daily['close']

# %%
tech_daily_scaled
# Out:
#            rsi       adx       cci       ema     stoch    close
# 0    -0.944828  0.768905 -0.569688  3.619104 -0.689365  129.140
# 1    -0.836055  0.724703 -0.456183  3.611090 -0.494532  129.300
# 2    -1.110909  0.725975 -0.651915  3.597864 -1.286041  128.650
# 3    -0.904027  0.732172 -0.682655  3.588563 -0.922752  128.940
# 4    -1.081838  0.743965 -0.809017  3.576378 -1.389339  128.530
# ...        ...       ...       ...       ...       ...      ...
# 9608 -0.571778 -0.994746 -0.929301  0.898408 -0.545157  101.447
# 9609 -0.539960 -0.940137 -0.715570  0.893785 -0.489640  101.482
# 9610 -0.362450 -0.988332 -0.122586  0.891348  0.045040  101.672
# 9611  0.027623 -1.037415  0.524185  0.893216  1.354651  102.115
# 9612 -0.122706 -1.137630  0.714407  0.893252  0.682640  101.935
#
# [9613 rows x 6 columns]

# %%
split_fraction = 0.8
split_row = int(tech_daily.shape[0] * split_fraction)

#tech_daily_scaled = tech_daily_scaled[1:]

train_stock_data_return = tech_daily_scaled.iloc[:split_row]
valid_stock_data_return = tech_daily_scaled.iloc[split_row:]

# %%
time_steps = 4 # number of predictor timesteps
horizon = 1 # number of timesteps to be predicted
sequence_length = time_steps + horizon # determine sequence length

# %%
import numpy as np
import torch

def create_sequences(df, seq_length):
    df = df.values  # Convert DataFrame to numpy array
    
    n = df.shape[0]
    xs = np.zeros((n - seq_length, seq_length, df.shape[1]))
    ys = np.zeros((n - seq_length, 1))
    
    for i in range(n - seq_length):
        xs[i] = df[i:(i+seq_length)]
        ys[i] = df[i+seq_length, -1]  # predict the 'return' column one step ahead
    
    # Convert to PyTorch tensors
    X = torch.from_numpy(xs)
    y = torch.from_numpy(ys)
    
    return X, y

# %%
train, train_target = create_sequences(train_stock_data_return, sequence_length)
valid, valid_target = create_sequences(valid_stock_data_return, sequence_length)

full_set, full_target = create_sequences(tech_daily_scaled, sequence_length)

# %%
from torch.utils.data import Dataset

class SequenceDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# %%
import torch
import torch.nn as nn

class MultivariateLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(MultivariateLSTM, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        self.fc1 = nn.Linear(hidden_size, 10)
        self.fc2 = nn.Linear(10, 1)
        #self.fc3 = nn.Linear(10, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        
        out = self.fc1(out[:, -1, :])
        out = self.fc2(out)
        #out = self.fc3(out)
        
        return out

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

# %%
from torch.utils.data import DataLoader
import copy

def train_model(model, train, train_target, valid, valid_target, learning_rate, num_epochs):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    #criterion = nn.MSELoss()
    criterion = RMSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    train_dataset = SequenceDataset(train, train_target)
    val_dataset = SequenceDataset(valid, valid_target)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = float('inf')

    train_losses = []
    val_losses = []

    best_predictions = []
    for epoch in range(num_epochs):
        model.train()
        train_epoch_losses = []
        for sequences, targets in train_loader:
            sequences = sequences.float().to(device)  # Convert to float
            targets = targets.float().to(device)  # Convert to float


            # Forward pass
            outputs = model(sequences)
            loss = criterion(outputs, targets)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_epoch_losses.append(loss.item())

        model.eval()
        val_epoch_losses = []
        with torch.no_grad():
            for sequences, targets in val_loader:
                sequences = sequences.float().to(device)  # Convert to float
                targets = targets.float().to(device)  # Convert to float


                outputs = model(sequences)
                loss = criterion(outputs, targets)
                val_epoch_losses.append(loss.item())
     
        train_loss = np.mean(train_epoch_losses)
        val_loss = np.mean(val_epoch_losses)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
             
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, '
              f'Validation Loss: {val_loss:.4f}')


        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), 'best_model.pth')  # Save the model
            best_epoch = epoch


    # load best model weights
    model.load_state_dict(best_model_wts)

    print(f'Best Loss {best_loss}, Epoch = {best_epoch}')
    
    # Plot the train loss and validation loss per epoch
    plt.figure(figsize=(12, 8))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss per epoch')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # generate predictions based on the best model
    train_predictions = []
    valid_predictions = []
    with torch.no_grad():
        for sequences, _ in train_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)
            train_predictions.extend(outputs.cpu().numpy().flatten().tolist())

        for sequences, _ in val_loader:
            sequences = sequences.float().to(device)
            outputs = model(sequences)
            valid_predictions.extend(outputs.cpu().numpy().flatten().tolist())

    return model

# Use the function:
num_features = train.shape[-1]  # X is your input data
model = MultivariateLSTM(input_size=num_features, hidden_size=40, num_layers=2, output_size=1)
model = train_model(model, train, train_target, valid, valid_target, learning_rate=0.001, num_epochs=100)
# Out:
# Epoch 1/100, Train Loss: 65.4470, Validation Loss: 23.9298
# Epoch 2/100, Train Loss: 11.5922, Validation Loss: 6.3739
# Epoch 3/100, Train Loss: 4.0956, Validation Loss: 0.6960
# Epoch 4/100, Train Loss: 0.9319, Validation Loss: 0.5672
# Epoch 5/100, Train Loss: 0.8252, Validation Loss: 0.8001
# Epoch 6/100, Train Loss: 0.7525, Validation Loss: 0.6082
# Epoch 7/100, Train Loss: 0.7734, Validation Loss: 0.7636
# Epoch 8/100, Train Loss: 0.6988, Validation Loss: 0.5822
# Epoch 9/100, Train Loss: 0.6987, Validation Loss: 0.8057
# Epoch 10/100, Train Loss: 0.6810, Validation Loss: 0.8137
# Epoch 11/100, Train Loss: 0.6906, Validation Loss: 0.5214
# Epoch 12/100, Train Loss: 0.6688, Validation Loss: 0.8561
# Epoch 13/100, Train Loss: 0.7169, Validation Loss: 0.5382
# Epoch 14/100, Train Loss: 0.6752, Validation Loss: 0.5595
# Epoch 15/100, Train Loss: 0.6682, Validation Loss: 0.5672
# Epoch 16/100, Train Loss: 0.6868, Validation Loss: 0.5087
# Epoch 17/100, Train Loss: 0.6611, Validation Loss: 0.4954
# Epoch 18/100, Train Loss: 0.6728, Validation Loss: 0.9383
# Epoch 19/100, Train Loss: 0.6590, Validation Loss: 0.5097
# Epoch 20/100, Train Loss: 0.6583, Validation Loss: 0.9308
# Epoch 21/100, Train Loss: 0.6959, Validation Loss: 0.7047
# Epoch 22/100, Train Loss: 0.6643, Validation Loss: 0.5337
# Epoch 23/100, Train Loss: 0.6658, Validation Loss: 0.6148
# Epoch 24/100, Train Loss: 0.6457, Validation Loss: 0.5381
# Epoch 25/100, Train Loss: 0.6349, Validation Loss: 0.5890
# Epoch 26/100, Train Loss: 0.6586, Validation Loss: 0.7987
# Epoch 27/100, Train Loss: 0.6447, Validation Loss: 0.5886
# Epoch 28/100, Train Loss: 0.6321, Validation Loss: 0.5968
# Epoch 29/100, Train Loss: 0.6562, Validation Loss: 0.5051
# Epoch 30/100, Train Loss: 0.6291, Validation Loss: 0.5001
# Epoch 31/100, Train Loss: 0.6291, Validation Loss: 0.5353
# Epoch 32/100, Train Loss: 0.6324, Validation Loss: 0.5712
# Epoch 33/100, Train Loss: 0.6494, Validation Loss: 0.5336
# Epoch 34/100, Train Loss: 0.6198, Validation Loss: 0.5873
# Epoch 35/100, Train Loss: 0.6304, Validation Loss: 0.4690
# Epoch 36/100, Train Loss: 0.6358, Validation Loss: 0.5174
# Epoch 37/100, Train Loss: 0.6221, Validation Loss: 0.6735
# Epoch 38/100, Train Loss: 0.5991, Validation Loss: 0.4923
# Epoch 39/100, Train Loss: 0.6350, Validation Loss: 0.7931
# Epoch 40/100, Train Loss: 0.6314, Validation Loss: 0.5234
# Epoch 41/100, Train Loss: 0.6218, Validation Loss: 0.7152
# Epoch 42/100, Train Loss: 0.6248, Validation Loss: 0.6126
# Epoch 43/100, Train Loss: 0.6309, Validation Loss: 0.5124
# Epoch 44/100, Train Loss: 0.6059, Validation Loss: 0.5890
# Epoch 45/100, Train Loss: 0.6198, Validation Loss: 0.9868
# Epoch 46/100, Train Loss: 0.6264, Validation Loss: 0.5043
# Epoch 47/100, Train Loss: 0.5962, Validation Loss: 0.5371
# Epoch 48/100, Train Loss: 0.6500, Validation Loss: 0.4939
# Epoch 49/100, Train Loss: 0.6226, Validation Loss: 0.6100
# Epoch 50/100, Train Loss: 0.6042, Validation Loss: 0.8243
# Epoch 51/100, Train Loss: 0.6092, Validation Loss: 0.4486
# Epoch 52/100, Train Loss: 0.6178, Validation Loss: 0.4568
# Epoch 53/100, Train Loss: 0.6094, Validation Loss: 0.5435
# Epoch 54/100, Train Loss: 0.6046, Validation Loss: 0.4589
# Epoch 55/100, Train Loss: 0.6179, Validation Loss: 0.4435
# Epoch 56/100, Train Loss: 0.6094, Validation Loss: 0.5574
# Epoch 57/100, Train Loss: 0.6146, Validation Loss: 0.4472
# Epoch 58/100, Train Loss: 0.6027, Validation Loss: 0.8421
# Epoch 59/100, Train Loss: 0.6186, Validation Loss: 0.5644
# Epoch 60/100, Train Loss: 0.5907, Validation Loss: 0.5533
# Epoch 61/100, Train Loss: 0.5997, Validation Loss: 0.4396
# Epoch 62/100, Train Loss: 0.5898, Validation Loss: 0.4744
# Epoch 63/100, Train Loss: 0.5950, Validation Loss: 0.5033
# Epoch 64/100, Train Loss: 0.6008, Validation Loss: 0.4778
# Epoch 65/100, Train Loss: 0.6012, Validation Loss: 0.7080
# Epoch 66/100, Train Loss: 0.5981, Validation Loss: 0.4431
# Epoch 67/100, Train Loss: 0.6172, Validation Loss: 0.5301
# Epoch 68/100, Train Loss: 0.6069, Validation Loss: 0.5105
# Epoch 69/100, Train Loss: 0.5916, Validation Loss: 0.5538
# Epoch 70/100, Train Loss: 0.5879, Validation Loss: 0.4376
# Epoch 71/100, Train Loss: 0.5788, Validation Loss: 0.6236
# Epoch 72/100, Train Loss: 0.5807, Validation Loss: 0.4575
# Epoch 73/100, Train Loss: 0.5860, Validation Loss: 0.4657
# Epoch 74/100, Train Loss: 0.6015, Validation Loss: 0.4717
# Epoch 75/100, Train Loss: 0.5766, Validation Loss: 0.5219
# Epoch 76/100, Train Loss: 0.6092, Validation Loss: 0.7005
# Epoch 77/100, Train Loss: 0.6116, Validation Loss: 0.6681
# Epoch 78/100, Train Loss: 0.5979, Validation Loss: 0.5179
# Epoch 79/100, Train Loss: 0.5934, Validation Loss: 0.4929
# Epoch 80/100, Train Loss: 0.5709, Validation Loss: 0.5102
# Epoch 81/100, Train Loss: 0.5793, Validation Loss: 0.4813
# Epoch 82/100, Train Loss: 0.5867, Validation Loss: 0.6216
# Epoch 83/100, Train Loss: 0.5998, Validation Loss: 0.4586
# Epoch 84/100, Train Loss: 0.5792, Validation Loss: 0.4280
# Epoch 85/100, Train Loss: 0.6047, Validation Loss: 0.4364
# Epoch 86/100, Train Loss: 0.5905, Validation Loss: 0.4840
# Epoch 87/100, Train Loss: 0.5689, Validation Loss: 0.4780
# Epoch 88/100, Train Loss: 0.5857, Validation Loss: 0.9151
# Epoch 89/100, Train Loss: 0.5875, Validation Loss: 0.5655
# Epoch 90/100, Train Loss: 0.5724, Validation Loss: 0.4462
# Epoch 91/100, Train Loss: 0.5890, Validation Loss: 0.4680
# Epoch 92/100, Train Loss: 0.5733, Validation Loss: 0.5099
# Epoch 93/100, Train Loss: 0.5667, Validation Loss: 0.4382
# Epoch 94/100, Train Loss: 0.6093, Validation Loss: 0.4605
# Epoch 95/100, Train Loss: 0.5735, Validation Loss: 0.4318
# Epoch 96/100, Train Loss: 0.5862, Validation Loss: 0.4447
# Epoch 97/100, Train Loss: 0.5940, Validation Loss: 0.5325
# Epoch 98/100, Train Loss: 0.6180, Validation Loss: 0.4522
# Epoch 99/100, Train Loss: 0.5757, Validation Loss: 0.4915
# Epoch 100/100, Train Loss: 0.5783, Validation Loss: 0.6654
# Best Loss 0.4279869278271993, Epoch = 83

# %%
def create_predictions(df, model):

  dataset = SequenceDataset(df, full_target)
  data_loader = DataLoader(dataset, batch_size=32, shuffle=True)
  model.eval()

  predictions = []
  with torch.no_grad():
      for sequences, _ in data_loader:
          sequences = sequences.float().to(device)
          outputs = model(sequences)
          predictions.extend(outputs.cpu().numpy().flatten().tolist())

  return predictions

# %%
predictions = create_predictions(full_set, model)

# %%
len(predictions)
# Out:
# 9608

# %%
predictions = [0]*5 + predictions

# %%
len(predictions)
# Out:
# 9613

# %%
len(tech_daily)
# Out:
# 9613

# %%
tech_daily['predictions'] = predictions

# %%
plotting_df = tech_daily[len(tech_daily)-500:]

# %%
plt.figure(figsize=(12, 8))
plt.plot(plotting_df['close'], label='Real closing price')
plt.plot(plotting_df['predictions'], label='Predictions')
plt.title('Real vs Predictions')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
